# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 取出今天所有的發文
# * ② 如果想要依照類別分類，怎麼儲存會比較好？
# * ③ 哪一個類別的文章最多

# %% [markdown]
# ### ① 取出今天所有的發文

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ettoday.net/news/news-list.htm'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebSite" lang="zh-Hant" prefix="og:http://ogp.me/ns#" xmlns:wb="http://open.weibo.com/wb">
#  <head>
#   <meta charset="utf-8"/>
#   <!-- ★★★以下非共用★★★ 開始 -->
#   <meta content="noarchive" name="robots"/>
#   <title>
#    新聞總覽 | ETtoday新聞雲
#   </title>
#   <link href="https://www.ettoday.net/news/news-list-2020-03-08-0.htm" rel="canonical"/>
#   <!-- 網頁社群分享meta 開始 -->
#   <meta content="https://www.ettoday.net/news/news-list-2020-03-08-0.htm" itemprop="url" property="og:url"/>
#   <meta content="新聞總覽 | ETtoday新聞雲" itemprop="name" property="og:title"/>
#   <meta content="https://cdn2.ettoday.net/style/ettoday2017/images/push.jpg" itemprop="image" property="og:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="628" property="og:image:height"/>
#   <meta content="article" property="og:type"/>
# ...

# %%
catlist = []
for d in soup.find(class_="part_list_2").find_all('h3'):
    cat = d.find('em').text
    if cat not in catlist:
        catlist.append(cat)

# %%
catdict = {}

for cat in catlist:
    catdict[cat]=[]

# %%
for key in d1.keys():
    print("關於『{}』有 {} 則".format(key, len(d1[key])))
# Out:
# 關於『健康』有 2 則
# 關於『生活』有 7 則
# 關於『體育』有 13 則
# 關於『國際』有 9 則
# 關於『時尚』有 3 則
# 關於『影劇』有 20 則
# 關於『房產雲』有 4 則
# 關於『大陸』有 4 則
# 關於『旅遊』有 2 則
# 關於『社會』有 6 則
# 關於『政治』有 10 則
# 關於『寵物動物』有 10 則
# 關於『3C家電』有 3 則
# 關於『網搜』有 1 則
# 關於『地方』有 3 則
# 關於『ET車雲』有 1 則
# 關於『軍武』有 1 則
# 關於『論壇』有 1 則

# %%
d1 = {}
for d in soup.find(class_="part_list_2").find_all("h3"):
    category = d.find("em").text
    value = (d.find(class_="date").text, d.find("a").text)
    d1.setdefault(category,[]).append(value)

# %% [markdown]
# ### ② 如果想要依照類別分類，怎麼儲存會比較好？

# %%
d1 = {}
for d in soup.find(class_="part_list_2").find_all("h3"):
    category = d.find("em").text
    value = (d.find(class_="date").text, d.find("a").text)
    d1.setdefault(category,[]).append(value)

# %% [markdown]
# ### ③ 哪一個類別的文章最多

# %%
amounts = []
for key in d1.keys():
    print("關於『{}』有 {} 則".format(key, len(d1[key])))
    amounts.append(len(d1[key]))
print("\n")
for key in d1.keys():
    if len(d1[key]) == max(amounts):
        print("類別最多的文章為『{}』，共有 {} 則".format(key, len(d1[key])))
# Out:
# 關於『健康』有 2 則
# 關於『生活』有 7 則
# 關於『體育』有 13 則
# 關於『國際』有 9 則
# 關於『時尚』有 3 則
# 關於『影劇』有 20 則
# 關於『房產雲』有 4 則
# 關於『大陸』有 4 則
# 關於『旅遊』有 2 則
# 關於『社會』有 6 則
# 關於『政治』有 10 則
# 關於『寵物動物』有 10 則
# 關於『3C家電』有 3 則
# 關於『網搜』有 1 則
# 關於『地方』有 3 則
# 關於『ET車雲』有 1 則
# 關於『軍武』有 1 則
# 關於『論壇』有 1 則
#
#
# 類別最多的文章為『影劇』，共有 20 則

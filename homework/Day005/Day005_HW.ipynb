# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

import requests
r = requests.get(' https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

import json
x=json.loads(response)

# %%
response
# Out:
# '[{"id":233160909,"title":"是多麼喜歡","excerpt":"從姊姊房間偷叼走一隻熊，是有奪喜歡🤣","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2020-02-29T05:52:42.475Z","updatedAt":"2020-02-29T05:52:42.475Z","commentCount":5,"likeCount":216,"withNickname":true,"tags":[],"topics":["貓"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"M","school":"斑a老爸","department":"ban_0815","replyTitle":null,"mediaMeta":[{"id":"7f39d296-b50f-4a4a-a6b0-391e33540caa","url":"https://megapx-assets.dcard.tw/images/40558a82-697c-43d1-bf70-9d41780881db/640.jpeg","normalizedUrl":"https://megapx-assets.dcard.tw/images/40558a82-697c-43d1-bf70-9d41780881db/640.jpeg","thumbnail":"https://megapx-assets.dcard.tw/images/40558a82-697c-43d1-bf70-9d41780881db/640.jpeg","type":"image/thumbnail","tags":[],"createdAt":"2020-02-29T05:52:42.475Z","updatedAt":"2020-02-29T05:52:42.475Z","width":480,"height":640},{"id":"7f39d296-b50f-4a4a-a6b0-391e33540caa","url":"https://megapx-assets.dcard.tw/images/40558a82-697c-43d1-bf70-9d41780881db/1280.jpeg","normalizedUrl":"https://megapx.dcard.tw/v1/images/40558a82-697c-43d1-bf70-9d41780881db","thumbnail":"https://megapx-assets.dcard.tw/images/40558a82-697c-43d1-bf70-9d41780881db/640.jpeg","type":"image/megapx","tags":[],"createdAt":"2020-02-29T05:52:42.475Z","updatedAt":"2020-02-29T05:52:42.475Z","width":1500,"height":2000}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":210},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":6}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":false,"media":[{"url":"https://megapx-assets.dcard.tw/images/40558a82-697c-43d1-bf70-9d41780881db/1280.jpeg"}],"reportReasonText":"","postAvatar":""},{"id":233161992,"title":"曬貓🥰路上救來的小賓士成長過程🤣","excerpt":"暑修的路上看到了在雙黃線上的小貓貓，下車去救他 他因為怕生跑到了水溝蓋上，在跑的時候明顯右腳有受傷，很瘦弱 卻很兇，因為是貓還小 怕會有母貓回來找，加上他又一直挖水溝蓋，所以隔了一天看到他還在，就把他","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2020-02-29T09:37:52.029Z","updatedAt":"2020-02-29T14:07:33.404Z","commentCount":5,"likeCount":159,"withNickname":false,"tags":[],"topics":["貓","賓士","成長","過程","貓咪"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"靜宜大學","replyTitle":null,"mediaMeta":[{"id":"95194d55-0c5e-4881-8333-5fce2209a27a","url":"https://megapx-assets.dcard.tw/images/fba27571-cab3-4bb4-8331-960bfd052975/640.jpeg","normalizedUrl":"https://megapx-assets.dcard.tw/images/fba27571-cab3-4bb4-8331-960bfd052975/640.jpeg","thumbnail":"https://megapx-assets.dcard.tw/images/fba27571-cab3-4bb4-8331-960bfd052975/640.jpeg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2020-02-29T09:37:52.029Z","updatedAt":"2020-02-29T14:07:33.404Z","width":397,"height":640},{"id":"95194d55-0c5e-4881-8333-5fce2209a27a","url":"https://megapx-assets.dcard.tw/images/fba27571-cab3-4bb4-8331-960bfd052975/full.jpeg","normalizedUrl":"https://megapx.dcard.tw/v1/images/fba27571-cab3-4bb4-8331-960bfd052975","thumbnail":"https://megapx-assets.dcard.tw/images/fba27571-cab3-4bb4-8331-960bfd052975/640.jpeg","type":"image/megapx","tags":["ANNOTATED"],"createdAt":"2020-02-29T09:37:52.029Z","updatedAt":"2020-02-29T14:07:33.404Z","width":635,"height":1023},{"id":"19b5225e-5029-46a2-9752-6c3ee7c7a829","url":"https://megapx-assets.dcard.tw/images/da0d4956-2127-48b1-a6c2-ea453d45b0b7/full.jpeg","normalizedUrl":"https://megapx.dcard.tw/v1/images/da0d4956-2127-48b1-a6c2-ea453d45b0b7","thumbnail":"https://megapx-assets.dcard.tw/images/da0d4956-2127-48b1-a6c2-ea453d45b0b7/640.jpeg","type":"image/megapx","tags":["ANNOTATED"],"createdAt":"2020-02-29T09:37:52.029Z","updatedAt":"2020-02-29T14:07:33.404Z","width":960,"height":1280},{"id":"11fcab51-1df8-45cf-a28b-e303976bb7bc","url":"https://megapx-assets.dcard.tw/images/58992b1b-e89d-4a11-ae1a-9dfdc43d08c2/full.jpeg","normalizedU ...

# %%
print(len(x))
# Out:
# 30

# %%
print(len(x[0])) #x是list; x[0]dict
# Out:
# 33

# %%
x[0].keys()
# Out:
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

for n in range(len(x)):
    print('第',n+1,'則')
    y = x[n]
    print('標題:',y['title'],'; 貼文時間:',y['createdAt'], '; 留言人數: ', y['commentCount'], '; 按讚人數: ', y['likeCount']  )
# Out:
# 第 1 則
# 標題: 是多麼喜歡 ; 貼文時間: 2020-02-29T05:52:42.475Z ; 留言人數:  5 ; 按讚人數:  216
# 第 2 則
# 標題: 曬貓🥰路上救來的小賓士成長過程🤣 ; 貼文時間: 2020-02-29T09:37:52.029Z ; 留言人數:  5 ; 按讚人數:  159
# 第 3 則
# 標題: 我只是想打個哈欠🥱 ; 貼文時間: 2020-02-28T16:44:58.714Z ; 留言人數:  7 ; 按讚人數:  68
# 第 4 則
# 標題: 純粹想曬曬我家柯基🐶 ; 貼文時間: 2020-02-29T03:59:09.926Z ; 留言人數:  3 ; 按讚人數:  46
# 第 5 則
# 標題: 問 狗狗品種 ; 貼文時間: 2020-02-29T03:03:15.315Z ; 留言人數:  11 ; 按讚人數:  37
# 第 6 則
# 標題: 最chill的邊境 ; 貼文時間: 2020-02-29T01:18:56.165Z ; 留言人數:  5 ; 按讚人數:  31
# 第 7 則
# 標題: 這位同學！請交出你的貓！ ; 貼文時間: 2020-02-28T18:50:36.643Z ; 留言人數:  3 ; 按讚人數:  24
# 第 8 則
# 標題: 小鳥倒掉 ; 貼文時間: 2020-02-29T13:03:28.751Z ; 留言人數:  1 ; 按讚人數:  23
# 第 9 則
# 標題: 長榮同學！交出你的鼠鼠！ ; 貼文時間: 2020-02-29T08:25:18.400Z ; 留言人數:  7 ; 按讚人數:  19
# 第 10 則
# 標題: 只是想給大家看看芋仔 ; 貼文時間: 2020-02-29T10:02:55.703Z ; 留言人數:  0 ; 按讚人數:  15
# 第 11 則
# 標題: 朋友打算棄養 ; 貼文時間: 2020-02-29T06:33:22.172Z ; 留言人數:  13 ; 按讚人數:  14
# 第 12 則
# 標題: 蛇板？（有關掉預覽 ; 貼文時間: 2020-02-28T17:20:29.630Z ; 留言人數:  4 ; 按讚人數:  13
# 第 13 則
# 標題: 賓士貓送養 已結紮&預防針 ; 貼文時間: 2020-02-29T03:06:56.553Z ; 留言人數:  3 ; 按讚人數:  11
# 第 14 則
# 標題: 限時的貓咪 ; 貼文時間: 2020-02-29T17:45:21.289Z ; 留言人數:  2 ; 按讚人數:  10
# 第 15 則
# 標題: 臘腸PK貓咪 壓在地上打！ ; 貼文時間: 2020-02-29T04:20:14.030Z ; 留言人數:  0 ; 按讚人數:  10
# 第 16 則
# 標題: 曬一下新來的小可愛😊 ; 貼文時間: 2020-02-29T18:36:31.491Z ; 留言人數:  2 ; 按讚人數:  8
# 第 17 則
# 標題: 寵物電繪🐶🐱（免費 3/01中午止 ; 貼文時間: 2020-02-29T15:53:52.068Z ; 留言人數:  24 ; 按讚人數:  8
# 第 18 則
# 標題: 文鳥養成 ; 貼文時間: 2020-02-29T07:51:17.328Z ; 留言人數:  0 ; 按讚人數:  8
# 第 19 則
# 標題: 史上最讚的狗狗 ; 貼文時間: 2020-02-28T22:19:39.904Z ; 留言人數:  0 ; 按讚人數:  8
# 第 20 則
# 標題: #圖#影小柴→大柴 ; 貼文時間: 2020-02-28T17:16:37.117Z ; 留言人數:  0 ; 按讚人數:  8
# 第 21 則
# 標題: 曬照片٩(｡・ω・｡)﻿و ; 貼文時間: 2020-02-29T15:53:09.766Z ; 留言人數:  0 ; 按讚人數:  7
# 第 22 則
# 標題: 成為馴獸師！ ; 貼文時間: 2020-02-28T19:56:09.767Z ; 留言人數:  3 ; 按讚人數:  7
# 第 23 則
# 標題: 問 貓咪突然親近的原因 ; 貼文時間: 2020-02-29T19:09:13.044Z ; 留言人數:  1 ; 按讚人數:  6
# 第 24 則
# 標題: 領養第三天 ; 貼文時間: 2020-02-29T15:30:49.969Z ; 留言人數:  4 ; 按讚人數:  6
# 第 25 則
# 標題: 貓咪3擇1 ; 貼文時間: 2020-02-29T01:03:41.600Z ; 留言人數:  14 ; 按讚人數:  6
# 第 26 則
# 標題: 豹紋守宮中的巨人 ; 貼文時間: 2020-02-28T16:42:37.872Z ; 留言人數:  6 ; 按讚人數:  6
# 第 27 則
# 標題: #法鬥#狗 如何幫你家狗打扮呢？ ; 貼文時間: 2020-02-29T15:20:01.741Z ; 留言人數:  0 ; 按讚人數:  4
# 第 28 則
# 標題: 有誰的臉比我更G8? ; 貼文時間: 2020-02-29T05:08:21.698Z ; 留言人數:  8 ; 按讚人數:  4
# 第 29 則
# 標題: 三重 協尋貓咪
# 請大家幫忙留意~謝謝 QAQ ; 貼文時間: 2020-03-01T01:23:57.748Z ; 留言人數:  0 ; 按讚人數:  3
# 第 30 則
# 標題: 用動作代表一切的貓 ; 貼文時間: 2020-02-29T14:24:16.068Z ; 留言人數:  1 ; 按讚人數:  3

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
initialpfc = 0
initialplc = 0
for n in range(len(x)):
    y = x[n]
    pfc = y['commentCount']
    initialpfc = pfc + initialpfc
    plc = y['likeCount']
    initialplc = plc +initialplc
print("平均留言數：{:f}\n平均按讚人數：{:f}".format(initialpfc/len(x),initialplc/len(x)))
# Out:
# 平均留言數：4.400000
# 平均按讚人數：26.266667

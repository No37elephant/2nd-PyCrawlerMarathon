# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests
url = "https://progressbar.tw/posts/234"
r =requests.get(url)
r.text
# Out:
# '<!DOCTYPE html>\n<html lang="zh-TW">\n<head>\n<meta charset="UTF-8">\n<title>要怎麼辨別使用者瀏覽者用哪種瀏覽器呢？用UserAgent是最簡單的方式喔！</title>\n<meta name="title" content="要怎麼辨別使用者瀏覽者用哪種瀏覽器呢？用UserAgent是最簡單的方式喔！">\n<meta http-equiv="Cache-control" content="public">\n<meta http-equiv="content-language" content="zh-tw">\n<meta http-equiv="max-age" content="604800">\n<meta name="robots" content="index, follow">\n<link rel="canonical" href="https://progressbar.tw/posts/234">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="language" content="zh-TW">\n<meta property="fb:app_id" content="373391753044058">\n<meta name="description" content="是爬蟲還是手機？淺談網路訪問的識別證UserAgent">\n<meta name="copyright" content="思誠科技有限公司">\n<meta name="author" content="進度條線上教學">\n<meta name="google-site-verification" content="a5vww6zDFkgPWTcT2fHyr-PQR5hAXX-F1OXM_sYTC8I" />\n<meta property="fb:pages" content="1424227107627646" />\n<meta property="og:type" content="website">\n<meta property="og:url" content="https://progressbar.tw/posts/234">\n<meta property="og:site_name" content="進度條Progress Bar程式線上教學">\n<meta property="og:locale" content="zh_TW">\n<meta property="og:title" content="要怎麼辨別使用者瀏覽者用哪種瀏覽器呢？用UserAgent是最簡單的方式喔！">\n<meta property="og:image" content="https://progressbar.tw/uploads/post/card_image/234/Cover234.jpg">\n<meta property="og:image:secure_url" content="https://progressbar.tw/uploads/post/card_image/234/Cover234.jpg">\n<meta property="og:image:width" content="800" />\n<meta property="og:description" content="是爬蟲還是手機？淺談網路訪問的識別證UserAgent">\n<meta name="image" content="https://progressbar.tw/uploads/post/card_image/234/Cover234.jpg">\n<link rel="icon" href="/favicon.ico">\n<link rel="manifest" href="https://progressbar.tw/assets/icons/manifest-27eca3e8297eb7ff340deb3849b210185a459b3845456aa4d0036f6d966b3518.json">\n<meta name="msapplication-TileColor" content="#ffffff">\n<meta name="msapplication-TileImage" href="https://progressbar.tw/assets/icons/ms-icon-144x144-91f3810843503ce7a69429b8ee6f4e38872d9c3ff255ca7cd3e72746cd1b2b1b.png">\n<meta name="theme-color" content="#382d5e">\n<script type="application/ld+json">\n{\n  "@context":"http://schema.org",\n  "@type":"NewsArticle",\n  "image":{\n    "@type":"ImageObject",\n    "width":1440,"height":810,\n    "url":"https://progressbar.tw/uploads/post/card_image/234/Cover234.jpg"\n  },\n  "url":"https://progressbar.tw/posts/234",\n  "headline":"要怎麼辨別使用者瀏覽者用哪種瀏覽器呢？用UserAgent是最簡單的方式喔！",\n  "thumbnailUrl":"https://progressbar.tw/uploads/post/card_image/234/Cover234.jpg",\n  "keywords":[\n    "Tag:Coding","Tag:Swift",\n    "Tag:Beginner",\n    "Tag:iOS App Development",\n    "Tag:Online Courses",\n    "Publication:yiyi-network",\n    "LockedPostSource:0",\n    "Elevated:false",\n    "LayerCake:0"\n    ],\n  "author":{\n    "@type":"Organization ",\n    "name":"進度條Progress Bar程式線上教學",\n    "url":"https://progressbar.tw"\n  },\n  "creator":["進度條Progress Bar程式線上教學"],\n  "publisher":{\n    "@type":"Organization",\n    "name":"進度條Progress Bar程式線上教學",\n    "url":"https://progressbar.tw",\n    "logo":{\n      "@type":"ImageObject",\n      "width":144,\n      "height":144,\n      "url":"https://progressbar.tw/assets/icons/ms-icon-144x144-91f3810843503ce7a69429b8ee6f4e38872d9c3ff255ca7cd3e72746cd1b2b1b.png"\n    }\n  },\n  "mainEntityOfPage":"https://progressbar.tw/posts/234"\n  }\n</script>\n<link rel="stylesheet" media="all" href="/assets/application-7533c6bcf0d7ef1be54a5588afbc2ff0f4c974bdaf78f8ef636c6ba3be3834ee.css" />\n<link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">\n<script src="/assets/application-988edc4b73729756cbe11c357006d7d26f8c4db290634a57c20b8e4f460a2f0f.js"></script>\n<script src="https://code.jquery.com/ui/1.12.1/jquery-ui.min.js" integrity="sha256-VazP97ZCwtekAsvgPBSUwPFKdrwD3unUfSGVYrahUqU=" crossorigin="anonymous"></script>\n<!--[if IE]>\n<script src="//cdnjs.cloudflare.com/ajax/libs/es5-shim/4.2.0/es5-shim.min.js"></script>\n<script src="//cd ...

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
"""
Your Code Here
"""
# Out:
# '\nYour Code Here\n'
